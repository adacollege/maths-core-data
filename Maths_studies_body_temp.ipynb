# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
body_temp_file_name = "average_temp_men.csv"
body_temp = pd.read_csv(body_temp_file_name)
body_temp
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-741e011e126e> in <module>()
#       1 body_temp_file_name = "average_temp_men.csv"
# ----> 2 body_temp = pd.read_csv(body_temp_file_name)
#       3 body_temp
#
# ...

# %%
sns.barplot(x=body_temp.index, y=body_temp['Mean average temperature for men'])
set(xlabel= Data group)
# Out:
#   File "<ipython-input-6-5f64e33ea863>", line 2
#     set(xlabel= Data group)
#                          ^
# SyntaxError: invalid syntax

# %%
body_temp_file_name_2 = "average_temp_women.csv"
body_temp_2 = pd.read_csv(body_temp_file_name_2)
body_temp_2
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-3ddb07b82b0b> in <module>()
#       1 body_temp_file_name_2 = "average_temp_women.csv"
# ----> 2 body_temp_2 = pd.read_csv(body_temp_file_name_2)
#       3 body_temp_2
#
# ...

# %%
sns.barplot(x=body_temp_2.index, y=body_temp_2['Mean average temperature for women'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-eef91ee33595> in <module>()
# ----> 1 sns.barplot(x=body_temp_2.index, y=body_temp_2['Mean average temperature for women'])
#       2
#
# NameError: name 'body_temp_2' is not defined

# %%
cumulative_mens_file_name = "cumulative_mens_temp.csv"
cumulative_mens = pd.read_csv(cumulative_mens_file_name)
cumulative_mens
# Out:
#         Temperature  Frequency  Cumulative frequency
# 0  35.5 < x <= 35.7          1                     1
# 1  35.7 < x <= 35.9          1                     2
# 2  35.9 < x <= 36.1          2                     4
# 3  36.1 < x <= 36.3          9                    13
# 4  36.3 < x <= 36.5          6                    19
# 5  36.5 < x <= 36.7         14                    33
# 6  36.7 < x <= 36.9         12                    45
# 7  36.9 < x <= 37.1         11                    56
# 8  37.1 < x <= 37.3          6                    62
# 9  37.3 < x <= 37.5          3                    65

# %%
cumulative_temp_file_name = "cumulative_temp.csv"
cumulative_temp = pd.read_csv(cumulative_temp_file_name, index_col="Temperature")
cumulative_temp
# Out:
#                    Womens frequency  ...  Mens cumulative frequency
# Temperature                          ...
# 35.5 < x <= 35.7                  0  ...                        1.0
# 35.7 < x  <= 35.9                 2  ...                        2.0
# 35.9 < x <= 36.1                  1  ...                        4.0
# 36.1 < x <= 36.3                  3  ...                       13.0
# 36.3 < x  <= 36.5                 3  ...                       19.0
# 36.5 < x <= 36.7                 12  ...                       33.0
# 36.7 < x <= 36.9                 14  ...                       45.0
# 36.9 < x <= 37.1                 18  ...                       56.0
# 37.1 < x <= 37.3                  7  ...                       62.0
# 37.3 < x <= 37.5                  2  ...                       65.0
# 37.5 < x <= 37.7                  1  ...                        NaN
# 37.7 < x <= 37.9                  1  ...                        NaN
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(25,15))


plt.title("Cumulative frequency graph- Average temperature in both genders")


sns.lineplot(data= cumulative_temp)

# %%
temp_average_file_name = "average_temp.csv"
temp_average = pd.read_csv(temp_average_file_name )
temp_average
# Out:
#    Group   Mean average temperature for women  Mean average temperature for men
# 0       1                              36.646                            36.538
# 1       2                              36.838                            37.676
# 2       3                              36.892                            36.738
# 3       4                              36.946                            36.777
# 4       5                              37.123                            36.900

# %%
plt.figure(figsize=(40,20))



sns.catplot( kind="bar", data= temp_average)
sns.barplot(x=temp_average.index, y=temp_average['Mean average temperature for women'])
